# %%
import pandas as pd
import logging
import numpy as np
import sys
import matplotlib.pyplot as plt
from sklearn.cross_validation import train_test_split
from random import shuffle
from sklearn.base import BaseEstimator, RegressorMixin
from scipy.optimize import minimize
from sklearn.model_selection import GridSearchCV, PredefinedSplit
from sklearn.model_selection import ParameterGrid
from sklearn.metrics import mean_squared_error, make_scorer

from datetime import date
from datetime import time
from datetime import datetime
from datetime import timedelta
# %matplotlib inline


from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
#PLOT CONFUSION MATRIX
from sklearn.metrics import confusion_matrix
import itertools

#matrix inverse
from numpy.linalg import inv

#see the value of multiple statements at once
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

#retina resolution figure
# %config InlineBackend.figure_format = 'retina'

#default size of the graph
plt.rcParams['figure.figsize'] = (10.0, 8.0) 

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
col_rs = 'region_start_time'
col_es = 'episode_starts'
col_le = 'long_episodes'

# %%
# %%time
# %whos
# %ls
# Out:
# Variable              Type             Data/Info
# ------------------------------------------------
# BaseEstimator         type             <class 'sklearn.base.BaseEstimator'>
# GridSearchCV          ABCMeta          <class 'sklearn.model_sel<...>on._search.GridSearchCV'>
# InteractiveShell      MetaHasTraits    <class 'IPython.core.inte<...>eshell.InteractiveShell'>
# ParameterGrid         type             <class 'sklearn.model_sel<...>n._search.ParameterGrid'>
# PredefinedSplit       ABCMeta          <class 'sklearn.model_sel<...>._split.PredefinedSplit'>
# RegressorMixin        type             <class 'sklearn.base.RegressorMixin'>
# a                     int              1
# addepoch              function         <function addepoch at 0x10fb27620>
# b                     int              2
# base_epi              float64          102.451612903
# base_le               float64          0.225806451613
# col_es                str              episode_starts
# col_le                str              long_episodes
# col_rs                str              region_start_time
# confusion_matrix      function         <function confusion_matrix at 0x10b02b730>
# dat                   DataFrame             patient_id  device_s<...>433      7     1  False
# dat_agg               function         <function dat_agg at 0x104914950>
# dat_epi_agg           DataFrame               episode_starts\nep<...>27\n7.0          3.149963
# dat_epi_agg_std       DataFrame               episode_starts\nep<...>18\n7.0          0.892717
# dat_epi_agg_ste       DataFrame               episode_starts\nep<...>70\n7.0          0.056574
# dat_le_agg            DataFrame               long_episodes\nepo<...>857\n7.0         1.383929
# dat_le_agg_std        DataFrame               long_episodes\nepo<...>803\n7.0         0.470929
# dat_le_agg_ste        DataFrame               long_episodes\nepo<...>834\n7.0         0.132166
# dat_tup               tuple            n=5
# data_222_1            tuple            n=2
# data_222_2            tuple            n=2
# data_222_3            tuple            n=2
# data_231              tuple            n=2
# date                  type             <class 'datetime.date'>
# datetime              type             <class 'datetime.datetime'>
# end_222_1             datetime         2016-10-24 00:00:00
# end_222_2             datetime         2017-05-29 00:00:00
# end_222_3             datetime         2018-01-30 00:00:00
# end_231               datetime         2018-02-21 00:00:00
# epoch_label           function         <function epoch_label at 0x10f6f9730>
# filtertime            function         <function filtertime at 0x1a18363e18>
# firstnorm             function         <function firstnorm at 0x1a17ce81e0>
# inv                   function         <function inv at 0x10703aea0>
# itertools             module           <module 'itertools' (built-in)>
# keys                  list             n=8
# le_aug                function         <function le_aug at 0x10fbb00d0>
# logging               module           <module 'logging' from '/<...>3.5/logging/__init__.py'>
# make_scorer           function         <function make_scorer at 0x10b0c0d90>
# mean_squared_error    function         <function mean_squared_error at 0x10b0b4b70>
# minimize              function         <function minimize at 0x10a879b70>
# n                     int              8
# np                    module           <module 'numpy' from '/Us<...>kages/numpy/__init__.py'>
# num_per_epoch_222_1   int              31
# num_per_epoch_222_2   int              30
# num_per_epoch_222_3   int              31
# num_per_epoch_231     int              31
# pd                    module           <module 'pandas' from '/U<...>ages/pandas/__init__.py'>
# plot_epoch_mean       function         <function plot_epoch_mean at 0x10fba9bf8>
# plt                   module           <module 'matplotlib.pyplo<...>es/matplotlib/pyplot.py'>
# prep                  function         <function prep at 0x10f6d8378>
# raw_data_222          DataFrame              patient_id  device_<...>n[1037 rows x 17 columns]
# raw_data_231          DataFrame             patient_id  device_s<...>06    NaN  \n707    NaN
# shuffle               method           <bound method Random.shuf<...>bject at 0x7fce2d856418>>
# start_222_1           datetime         2016-02-12 00:00:00
# start_222_2           datetime         2016-10-26 00:00:00
# start_222_3           datetime         2017-09-19 00:00:00
# start_231             datetime         2017-02-07 00:00:00
# sys                   module           <module 'sys' (built-in)>
# thres                 float64          1.78463476071
# time                  type             <class 'datetime.time'>
# timedelta             type             <class 'datetime.timedelta'>
# train_test_split      function         <function train_test_split at 0x10b1a1e18>
# tup_222_1             tuple            n=4
# tup_222_2             tuple            n=4
# tup_222_3             tuple            n=4
# tup_231               tuple            n=4
# vals                  list             n=8
# Plot epoch performance-Copy1.ipynb  Plot epoch performance.ipynb
# CPU times: user 408 ms, sys: 31.2 ms, total: 439 ms
# Wall time: 543 ms

# %%
np.mean
### shift + tab
# Out:
# Plot epoch performance-Copy1.ipynb  Plot epoch performance.ipynb

# %%
def filtertime(dat, start_date, end_date):
    return np.array(start_date <= dat[col_rs]) & \
         np.array(dat[col_rs] <= end_date)

# %%
def addepoch(dat, start, end, num_per_epoch):
    
    c = end - start
    num_epoch  = int(np.floor(c.days/num_per_epoch))
    start_dates = [start + timedelta(days = i * num_per_epoch) for i in range(num_epoch)]
    end_dates = [start + timedelta(days = (i + 1) * num_per_epoch) for i in range(num_epoch)]
    dates = list(zip(start_dates, end_dates))
    end = dates[-1][-1]
    for i in range(num_epoch):
        date_tup = dates[i]
        dstart, dend = date_tup[0],date_tup[1]
        dat.loc[filtertime(dat, dstart, dend),'epoch'] = int(i)
    data = dat[np.array(start <= dat.loc[:,col_rs]) & \
         np.array(dat.loc[:,col_rs] <= end)]
    data.loc[:,'epoch'] = data.loc[:,'epoch'].astype(int)
    return data

# %%
def epoch_label(dat_tup):
    dat = dat_tup[0]
    dat_epi_agg, dat_le_agg, dat_epi_agg_ste, dat_le_agg_ste = dat_agg(dat)
    n = dat_epi_agg.shape[0]
    thres = np.median(dat_epi_agg)
    keys = list(np.array(dat_epi_agg.index, dtype = int))
    vals = list(np.array(dat_epi_agg.loc[:,col_es] < thres))
    epoch_label = dict(zip(keys, vals))
    for key in epoch_label:
        val = epoch_label[key]
        dat.loc[dat['epoch'] == key,'label'] = val
    data = (dat, dat_tup[1])
    return data

# %%
def le_aug(dat, multiplier):
    dat.loc[:,col_le] = multiplier * dat.loc[:,col_le]
    return dat

# %%
def firstnorm(dat, col):
    base = np.array(dat.loc[:,col])[0]
    dat.loc[:,col] = dat.loc[:,col] / base
    return dat, base

# %%
def prep(dat, start, end, num_per_epoch, patid):
    dat.loc[:,col_rs] = pd.to_datetime(dat.loc[:,col_rs])
    data_1 = addepoch(dat, start, end, num_per_epoch)
    cache = [start, end, num_per_epoch, patid]
    data_2 = (data_1, cache)
    data_3 = epoch_label(data_2)
    return data_3

# %%
def dat_agg(dat):
    N = dat.shape[0]
    dat_epi_agg = dat.loc[:, [col_es, 'epoch']].groupby('epoch').agg('mean')
    dat_epi_agg, base_epi = firstnorm(dat_epi_agg, col_es)
    dat_le_agg = dat.loc[:, [col_le, 'epoch']].groupby('epoch').agg('mean')
    dat_le_agg, base_le = firstnorm(dat_le_agg, col_le)
    dat_epi_agg_ste = dat.loc[:, [col_es, 'epoch']].groupby('epoch').std()/base_epi/np.sqrt(N)
    dat_le_agg_ste = dat.loc[:, [col_le, 'epoch']].groupby('epoch').std()/base_le/np.sqrt(N)
    
    return dat_epi_agg, dat_le_agg, dat_epi_agg_ste, dat_le_agg_ste

# %%
def plot_epoch_mean(dat_tup):
    dat = dat_tup[0]
    ptid = dat_tup[1][3]
    period_start = str(dat_tup[1][0])[:10]
    period_end = str(dat_tup[1][1])[:10]
    
    dat_epi_agg, dat_le_agg, dat_epi_agg_ste, dat_le_agg_ste = dat_agg(dat)
    plt.figure()
    plt.plot(dat_epi_agg, label = 'episodes start mean')
    plt.plot(dat_epi_agg + dat_epi_agg_ste,linestyle='dashed', label = 'episodes start mean + sem')
    plt.plot(dat_epi_agg - dat_epi_agg_ste,linestyle='dashed', label = 'episodes start mean - sem')
    plt.plot(dat_le_agg, label = 'long episode mean')
    plt.plot(dat_le_agg + dat_le_agg_ste,linestyle='dashed', label = 'long episode mean + sem')
    plt.plot(dat_le_agg - dat_le_agg_ste,linestyle='dashed', label = 'long episode mean - sem')
    plt.title('Patient {0}: period {1} - {2}'.format(ptid, period_start, period_end))
    plt.xlabel('epoch')
    plt.ylabel('count(nomalized)')
    plt.tight_layout()
    plt.legend()
    plt.show()

# %%
start_222_1 = datetime.strptime('Feb 12 2016', '%b %d %Y')
end_222_1 = datetime.strptime('Oct 24 2016', '%b %d %Y')
num_per_epoch_222_1 = 31

start_222_2 = datetime.strptime('Oct 26 2016', '%b %d %Y')
end_222_2 = datetime.strptime('May 29 2017', '%b %d %Y')
num_per_epoch_222_2 = 30

start_222_3 = datetime.strptime('Sep 19 2017', '%b %d %Y')
end_222_3 = datetime.strptime('Jan 30 2018', '%b %d %Y')
num_per_epoch_222_3 = 31


start_231 = datetime.strptime('Feb 7 2017', '%b %d %Y')
end_231 = datetime.strptime('Feb 21 2018', '%b %d %Y')
num_per_epoch_231 = 31

# %%
# %%debug
# data_222_1 = prep(raw_data_222, start_222_1, end_222_1, num_per_epoch_222_1, 222)
# data_222_2 = prep(raw_data_222, start_222_2, end_222_2, num_per_epoch_222_2, 222)
# data_222_3 = prep(raw_data_222, start_222_3, end_222_3, num_per_epoch_222_3, 222)
# data_231 = prep(raw_data_231, start_231, end_231, num_per_epoch_231, 231)
# Out:
# NOTE: Enter 'c' at the ipdb>  prompt to continue execution.
# > <string>(2)<module>()
#
# ipdb> c

# %%
plot_epoch_mean(data_222_1)
plot_epoch_mean(data_222_2)

plot_epoch_mean(data_222_3)

plot_epoch_mean(data_231)

# %%
# %%debug
# a = 1
# a += 1
# b+a
# Out:
# NOTE: Enter 'c' at the ipdb>  prompt to continue execution.
# > <string>(2)<module>()
#
# ipdb> c
